# %% [markdown]
# <a href="https://colab.research.google.com/github/tbhandurge/frb-blitzar-classifier/blob/main/frb_blitzar_classifier_(coding_interface).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import matplotlib
import dataclasses
# !pip install astropy
import astropy
# !pip install astroML
import astroML
# !pip install icecream
import icecream
# !pip install git+https://github.com/chime-experiment/ch_util.git
import ch_util
# Out:
# ...
#   Cloning https://github.com/chime-experiment/ch_util.git to /tmp/pip-req-build-jbrpclmw
#   Running command git clone --filter=blob:none --quiet https://github.com/chime-experiment/ch_util.git /tmp/pip-req-build-jbrpclmw
#   Resolved https://github.com/chime-experiment/ch_util.git to commit 2b0acbef89230de63ff861bcf48ae7004bb5e95f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/radiocosmology/caput.git to /tmp/pip-install-7puyagoq/caput_07571d36008548629fbd93ecb2d97178
#   Running command git clone --filter=blob:none --quiet https://github.com/radiocosmology/caput.git /tmp/pip-install-7puyagoq/caput_07571d36008548629fbd93ecb2d97178
#   Resolved https://github.com/radiocosmology/caput.git to commit e0640c92aabcd7dee7c454ba62e849f94b3d413b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
# ...

# %%
# !pip install git+https://github.com/CHIMEFRB/subpulse.git
import subpulse
# Out:
# ...
#   Cloning https://github.com/CHIMEFRB/subpulse.git to /tmp/pip-req-build-nd7p425y
#   Running command git clone --filter=blob:none --quiet https://github.com/CHIMEFRB/subpulse.git /tmp/pip-req-build-nd7p425y
#   Resolved https://github.com/CHIMEFRB/subpulse.git to commit 160832e3710afaf2f5ab40f0e5add830273e29a1
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# INFO: pip is looking at multiple versions of subpulse to determine which version is compatible with other requirements. This could take a while.
# ...
